# %%
import requests
import pyodbc
# %matplotlib inline
from pandas.testing import assert_frame_equal
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import statsmodels.formula.api as smf
#from sklearn.linear_model import LinearRegression
#from sklearn import metrics
#from sklearn.model_selection  import train_test_split
import numpy as np
#from scipy.stats import norm # for scientific Computing
#from scipy import stats, integrate
import matplotlib.pyplot as plt
# Out:
# C:\Users\shanh\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Write a function that accepts a string and returns whether a string is palindrome or not (Do not use in built methods, slice notations [::-1]). A string is called a palindrome string if the reverse of that string is the same as the original string.
#
# Example:-
# Input: radar
# Output True
#
# Input: Radio
# Output: False

# %%
def solutions(words):
    k=[]
    for i in words:
        if i==i[::-1]:
            k.append(True)
        else:k.append(False)
    return k
words=["hih","lol"]
print(solutions(words))
# Out:
# [True, True]

# %% [markdown]
# Write a function that accepts first_name as a parameter. The function should make an API call with the following specifications
#
# Method: GET
# URL: https://api.agify.io/
# Query parameter: name
#
# Pass the first name as value to query parameter. The API call return a JSON stating the predicted age and count (the total number of records based on which it made the prediction). The function should return the following as a String
#
# Output of the function should be as follows
# “The predicted age for name abc is 54 based on the total record count of 79”

# %%
import requests
response1 = requests.get("https://api.agify.io/")
print(response1)
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1638                     if errno != 0:
# -> 1639                         raise SysCallError(errno, errorcode.get(errno))
#    1640                 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (10054, 'WSAECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     346         if HAS_SNI and server_hostname is not None:
# --> 347             return context.wrap_socket(sock, server_hostname=server_hostname)
#     348
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     461             except OpenSSL.SSL.Error as e:
# --> 462                 raise ssl.SSLError('bad handshake: %r' % e)
#     463             break
#
# SSLError: ("bad handshake: SysCallError(10054, 'WSAECONNRESET')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='api.agify.io', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(10054, 'WSAECONNRESET')")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-4-6af478b1b033> in <module>
#       1 import requests
# ----> 2 response1 = requests.get("https://api.agify.io/")
#       3 print(response1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='api.agify.io', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: SysCallError(10054, 'WSAECONNRESET')")))

# %%
query = {'name': 'Tiangong'}
response = requests.get('https://api.agify.io/', params=query)
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1638                     if errno != 0:
# -> 1639                         raise SysCallError(errno, errorcode.get(errno))
#    1640                 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (10054, 'WSAECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     346         if HAS_SNI and server_hostname is not None:
# --> 347             return context.wrap_socket(sock, server_hostname=server_hostname)
#     348
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     461             except OpenSSL.SSL.Error as e:
# --> 462                 raise ssl.SSLError('bad handshake: %r' % e)
#     463             break
#
# SSLError: ("bad handshake: SysCallError(10054, 'WSAECONNRESET')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='api.agify.io', port=443): Max retries exceeded with url: /?name=Tiangong (Caused by SSLError(SSLError("bad handshake: SysCallError(10054, 'WSAECONNRESET')")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-5-beebf4fb1261> in <module>
#       1 query = {'name': 'Tiangong'}
# ----> 2 response = requests.get('https://api.agify.io/', params=query)
#       3 print(response.json())
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='api.agify.io', port=443): Max retries exceeded with url: /?name=Tiangong (Caused by SSLError(SSLError("bad handshake: SysCallError(10054, 'WSAECONNRESET')")))

# %% [markdown]
# Generic Rule for all CSV files
# 1.	The column names should be in lower snake case
# 2.	Use your inference to provide correct data type to the column values
# Reviews data frame
# 3.	Fill null values in Reviewer’s Name column as “Anonymous”
# Listing data frame
# 4.	Add a new Column (name it zone) based on following logic if city is Kitchener or Waterloo then “Zone A”, if city is Toronto, then “Zone B” and if City is Ottawa, then “Zone C”
# Combined data frame
# 5.	Join listing data frame with calendar and reviews data frame (Assume join key from understanding of the data provided)
# 6.	On the combined data frame, filter out records where availability is “F”
# 7.	Filter out listings which does not have any reviews (Also add a new column called review_flag and set true when a review exists)
# 8.	Add a new column called Currency and assign value USD to every row
# 9.	Create a new column called price_in_cad which is product of 1.3 * price columns
# 10.	Only columns in sample output are required

# %%
import pyodbc
import pandas as pd

list1 = pd.read_csv(r"C:\Users\shanh\Downloads\listings.csv")
rev = pd.read_csv(r"C:\Users\shanh\Downloads\reviews.csv")
calender = pd.read_csv(r"C:\Users\shanh\Downloads\calendar.csv")
# Some other example server values are
# server = 'localhost\sqlexpress' # for a named instance
# server = 'myserver,port' # to specify an alternate port
list1.columns=list1.columns.str.lower()
rev.columns=rev.columns.str.lower()

#print(rev['reviewer name'])

# %%
col_name='reviewer name'
#condition=rev_col.'reviewer name'=None
#rev_col.loc[rev_col.'reviewer name'="",col_name]='Anonymous'
rev['reviewer name']=rev['reviewer name'].fillna("Anonymous")
#print(rev_col1['reviewer name'])
#df['equal_or_lower_than_4?'] = df['set_of_numbers'].apply(lambda x: 'True' if x <= 4 else 'False')

#rev['reviewer name']=rev['reviewer name'].apply(lambda x:numpy.nan if x==float("nan") else x)
#newdf = df.loc[(df.origin == "JFK") & (df.carrier == "B6")]
#df2 = df[~pd.isnull(df['Courses'])]
rev2 = rev[~pd.isnull(rev['id'])]
list
# Out:
#    id                                               name       city  \
# 0   1                     Cozy place in Heart of Toronto    Toronto
# 1   2   Cozy place in Heart of Waterloo near water front   Waterloo
# 2   3     Cozy place in Heart of Ottawa near water front     Ottawa
# 3   4       Cozy place in Heart of Toronto near CN Tower    Toronto
# 4   5  Cozy place in Heart of Waterloo near Universit...   Waterloo
# 5   6  Cozy place in Heart of Ottawa near Parliament ...     Ottawa
# 6   7  Cozy place in Heart of Toronto near Financial ...    Toronto
# 7   8  Cozy place in Heart of Toronto near Distillery...    Toronto
# 8   9  Cozy place in Heart of Toronto near College St...    Toronto
# 9  10  Cozy place in Heart of Kitchener near Conestog...  Kitchener
#
#        host name  host response time
# 0       John Doe                   5
# 1       Jane Doe                   4
# 2      Cheng Doe                   3
# 3    Charles Doe                   2
# 4     Justin Doe                   1
# 5       Jung Doe                   4
# 6  Nicholoas Doe                   3
# 7    Rebbeca Doe                   2
# 8     Dmitry Doe                   2
# 9    Winston Doe                   1

# %% [markdown]
# Add a new Column (name it zone) based on following logic if city is Kitchener or Waterloo then “Zone A”, if city is Toronto, then “Zone B” and if City is Ottawa, then “Zone C” Combined data frame

# %% [markdown]
# #rev['reviewer name']=rev['reviewer name'].apply(lambda x:numpy.nan if x==float("nan") else x)
# list1['zone']=list1['city']
# df['age']=df['age'].apply(lambda x: x+3)
# df['new_column'] = np.where(df['col2']<9, 'value1',
#                    np.where(df['col2']<12, 'value2',
#                    np.where(df['col2']<15, 'value3', 'value4')))

# %%
list1['zone']=np.where((list1['city']=='Waterloo')|(list1['city']=='Kitchener'),'Zone A',
                      np.where(list1['city']=='Toronto','Zone B',
                               np.where(list1['city']=='Ottawa','Zone C','')
                              ))
#list1['zone']
rev2
# Out:
#    listing id    id                                 review description  \
# 0         1.0   1.0  Cute and cozy place. Perfect location to every...
# 1         2.0   2.0  Kelly has a great room in a very central location
# 2         1.0   3.0  Very spacious apartment and in a great neighbo...
# 3         3.0   4.0                        Great and Comfortable Place
# 4         4.0   5.0                               Far from attractions
# 5         5.0   6.0                                         Great view
# 6         1.0   7.0                                          Too noisy
# 7         3.0   8.0                                         Cozy place
# 8         3.0   9.0                                            Unclean
# 9         5.0  10.0                          The earth is like a ball.
#
#    reviewer name
# 0       John Doe
# 1       Jane Doe
# 2      Cheng Doe
# 3    Charles Doe
# 4     Justin Doe
# 5       Jung Doe
# 6  Nicholoas Doe
# 7      Anonymous
# 8      Anonymous
# 9    Winston Doe

# %%
#Q4
def f(x):
    if x['city']=="Toronto":
        return "ZoneB"
    elif x['city']=="Waterloo" or x['city']=='Kitchener':
        return "ZoneA"
    elif x['city']=="Ottawa": return "ZoneB"
#list1['zone']=list.apply(f(list1))
#list1['zone']

# %%
#Q55.	Join listing data frame with calendar and reviews data frame (Assume join key from understanding of the data provided)
#df=[df[],df[],df[]]

combine=list1.join(calender.set_index('Listing ID'), on='id')
combine.columns=combine.columns.str.lower()
#user merge or concat
#combine

# %%
#Q6On the combined data frame, filter out records where availability is “F”
#df[(df.val > 0.5) & (df.val2 == 1)]
combine1=combine[combine.availability=='T']
#df.filter(items=['one', 'three'])

#combine1
# Out:
#    id                                               name       city  \
# 0   1                     Cozy place in Heart of Toronto    Toronto
# 0   1                     Cozy place in Heart of Toronto    Toronto
# 0   1                     Cozy place in Heart of Toronto    Toronto
# 1   2   Cozy place in Heart of Waterloo near water front   Waterloo
# 1   2   Cozy place in Heart of Waterloo near water front   Waterloo
# 1   2   Cozy place in Heart of Waterloo near water front   Waterloo
# 1   2   Cozy place in Heart of Waterloo near water front   Waterloo
# 1   2   Cozy place in Heart of Waterloo near water front   Waterloo
# 1   2   Cozy place in Heart of Waterloo near water front   Waterloo
# 2   3     Cozy place in Heart of Ottawa near water front     Ottawa
# 2   3     Cozy place in Heart of Ottawa near water front     Ottawa
# 4   5  Cozy place in Heart of Waterloo near Universit...   Waterloo
# 4   5  Cozy place in Heart of Waterloo near Universit...   Waterloo
# 4   5  Cozy place in Heart of Waterloo near Universit...   Waterloo
# 6   7  Cozy place in Heart of Toronto near Financial ...    Toronto
# 7   8  Cozy place in Heart of Toronto near Distillery...    Toronto
# 8   9  Cozy place in Heart of Toronto near College St...    Toronto
# 9  10  Cozy place in Heart of Kitchener near Conestog...  Kitchener
#
#        host name  host response time    zone        date availability  price
# 0       John Doe                   5  Zone B  2022-02-01            T  125.0
# 0       John Doe                   5  Zone B  2022-02-02            T  125.0
# 0       John Doe                   5  Zone B  2022-02-03            T  125.0
# 1       Jane Doe                   4  Zone A  2022-02-02            T  125.0
# 1       Jane Doe                   4  Zone A  2022-02-03            T  125.0
# 1       Jane Doe                   4  Zone A  2022-02-04            T  250.0
# 1       Jane Doe                   4  Zone A  2022-02-05            T  250.0
# 1       Jane Doe                   4  Zone A  2022-02-22            T  250.0
# 1       Jane Doe                   4  Zone A  2022-02-07            T  125.0
# 2      Cheng Doe                   3  Zone C  2022-06-07            T  225.0
# 2      Cheng Doe                   3  Zone C  2022-06-07            T  225.0
# 4     Justin Doe                   1  Zone A  2022-02-04            T  145.0
# 4     Justin Doe                   1  Zone A  2022-02-05            T  195.0
# 4     Justin Doe                   1  Zone A  2022-02-06            T  195.0
# 6  Nicholoas Doe                   3  Zone B  2022-02-07            T  125.0
# 7    Rebbeca Doe                   2  Zone B  2022-02-07            T  150.0
# 8     Dmitry Doe                   2  Zone B  2022-02-07            T  125.0
# 9    Winston Doe                   1  Zone A  2022-02-07            T  135.0

# %%
#Q7Filter out listings which does not have any reviews (Also add a new column called review_flag and set true when a review exists)
#combine=combine1.join(rev.set_index('listing id','reviewer name'), on=('id','reviewer name'))

combine2=combine1.merge(rev, left_on=['id','host name'],right_on=['id','reviewer name'], how='left',indicator=True)

rev3 = combine2[~pd.isnull(combine2['review description'])]

# %%
#Add a new column called Currency and assign value USD to every row
#Create a new column called price_in_cad which is product of 1.3 * price columns

# %%
cnxn_str = ("Driver={SQL Server Native Client 11.0};"
            "Server=LAPTOP-0VCM797I\SAM;"
            "Database=Practice;"
            "Trusted_Connection=yes;")
cnxn = pyodbc.connect(cnxn_str)
cursor = cnxn.cursor()
cursor.execute("delete from Practice.dbo.listings")
# Insert Dataframe into SQL Server:
for index, row in df.iterrows():
    cursor.execute("INSERT INTO Practice.dbo.listings (id, name, city, host_name, host_response_time ) values(?,?,?,?,?)", row.id, row.name, row.city, row.host_name, row.host_response_time)
cnxn.commit()
cursor.close()

ata = pd.read_sql("SELECT *from Practice.dbo.listings", cnxn)
print(ata)
